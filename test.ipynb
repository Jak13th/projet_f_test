# %%
# !pip install pandas
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_json('xmltojson.json')

# %%
df.head()
# Out:
#                                                   formations
# formation  [{'identifiant': 'FOR.1026', 'code_scolarite':...

# %%
import json
# !pip install flask
from flask import jsonify
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'd:\users\thibaut\documents\hetic cours\projet final\env-projet-fin\scripts\python.exe -m pip install --upgrade pip' command.

# %%
with open('Onisep_Ideo_Fiches_Formations_19042022.json', encoding="utf8") as read_file:
    data = json.load(read_file)

# %%
data1 = pd.DataFrame.from_dict(data)

# %%
print(data)

# %%
data1.head()
# Out:
#                                                   formations
# formation  [{'identifiant': 'FOR.1026', 'code_scolarite':...

# %%
from yarl import URL

# %%
url = URL("https://github.com/search?q=data+science")

# %%
url.scheme
# Out:
# 'https'

# %%
url.host
# Out:
# 'github.com'

# %%
url.path
# Out:
# '/search'

# %%
df = pd.read_csv("ideo-metiers_onisep.csv", sep=";")

# %%
df.head()
# Out:
#                                       libellé métier  \
# 0  accompagnant éducatif et social / accompagnant...
# 1  accompagnateur / accompagnatrice en moyenne mo...
# 2                               acheteur / acheteuse
# 3                                           actuaire
# 4          administrateur / administratrice de biens
#
#                                  lien site onisep.fr  \
# 0  http://www.onisep.fr/http/redirection/metier/s...
# 1  http://www.onisep.fr/http/redirection/metier/s...
# 2  http://www.onisep.fr/http/redirection/metier/s...
# 3  http://www.onisep.fr/http/redirection/metier/s...
# 4  http://www.onisep.fr/http/redirection/metier/s...
#
#                                      nom publication            collection  \
# 0                  Les métiers au service des autres  Zoom sur les métiers
# 1                         Les métiers de la montagne              Parcours
# 2                  Les métiers de la mode et du luxe              Parcours
# ...

# %%
df.columns
# Out:
# Index(['libellé métier', 'lien site onisep.fr', 'nom publication',
#        'collection', 'année', 'gencod', 'GFE', 'code ROME', 'libellé ROME',
#        'lien ROME', 'domaine/sous-domaine'],
#       dtype='object')

# %%
list_to_drop = ["nom publication", "collection", "gencod", "GFE", "code ROME"]

# %%
df = df.drop(list_to_drop, axis=1)

# %%
df.head()
# Out:
#                                       libellé métier  \
# 0  accompagnant éducatif et social / accompagnant...
# 1  accompagnateur / accompagnatrice en moyenne mo...
# 2                               acheteur / acheteuse
# 3                                           actuaire
# 4          administrateur / administratrice de biens
#
#                                  lien site onisep.fr   année  \
# 0  http://www.onisep.fr/http/redirection/metier/s...  2019.0
# 1  http://www.onisep.fr/http/redirection/metier/s...  2018.0
# 2  http://www.onisep.fr/http/redirection/metier/s...  2019.0
# 3  http://www.onisep.fr/http/redirection/metier/s...  2015.0
# 4  http://www.onisep.fr/http/redirection/metier/s...  2020.0
#
#                                         libellé ROME  \
# 0                        Accompagnement médicosocial
# 1  Accompagnement de voyages, d'activités culture...
# 2                                              Achat
# 3                  Études actuarielles en assurances
# ...

# %%
# !pip install psycopg2
# !pip install sqlalchemy
import psycopg2
from sqlalchemy import create_engine
# Out:
# ...
#   Using cached psycopg2-2.9.3-cp39-cp39-win_amd64.whl (1.2 MB)
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'd:\users\thibaut\documents\hetic cours\projet final\env-projet-fin\scripts\python.exe -m pip install --upgrade pip' command.
# WARNING: You are using pip version 20.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'd:\users\thibaut\documents\hetic cours\projet final\env-projet-fin\scripts\python.exe -m pip install --upgrade pip' command.
# ...
#   Using cached greenlet-1.1.2-cp39-cp39-win_amd64.whl (101 kB)
# ...

# %%
conn_string = 'postgresql://postgres:whitebeard@localhost:5432/projet_final'

db = create_engine(conn_string)
conn = db.connect()

# %%
df.to_sql('data', con=conn, if_exists='replace',index=False)
conn = psycopg2.connect(conn_string)
conn.autocommit = True
cursor = conn.cursor()

# %%
sql1 = '''select * from data;'''
cursor.execute(sql1)
for i in cursor.fetchall():
    print(i)
# Out:
# ('accompagnant éducatif et social / accompagnante éducative et sociale', 'http://www.onisep.fr/http/redirection/metier/slug/MET.782', 2019.0, 'Accompagnement médicosocial', 'https://candidat.pole-emploi.fr/marche-du-travail/fichemetierrome?codeRome=K1301', 'santé - social - sport/travail social')
# ('accompagnateur / accompagnatrice en moyenne montagne', 'http://www.onisep.fr/http/redirection/metier/slug/MET.784', 2018.0, "Accompagnement de voyages, d'activités culturelles ou sportives", 'https://candidat.pole-emploi.fr/marche-du-travail/fichemetierrome?codeRome=G1201', 'santé - social - sport/sport| hôtellerie - restauration - tourisme/tourisme')
# ('acheteur / acheteuse', 'http://www.onisep.fr/http/redirection/metier/slug/MET.571', 2019.0, 'Achat', 'https://candidat.pole-emploi.fr/marche-du-travail/fichemetierrome?codeRome=M1101', 'commerce, marketing, vente/achat, approvisionnement| commerce, marketing, vente/grande distribution et petits commerces')
# ...

# %%
# conn.commit()
conn.close()
